# %% [markdown]
# <h1> Deep Learning Small Project </h1>

# %%
# %matplotlib inline

# Display
from IPython.display import Image

# Torch
import torch
from torch.utils.data import DataLoader
from torch import optim, nn

# Custom
import data
import model
import utils

# %% [markdown]
# Using Custom Dataloader, Data Split for First Layer classification task (normal vs infected)

# %%
fl_labels = {
0 : "Normal",
1 : "Infected"
}

fl_train = data.Lung_Dataset('train', verbose = 0)
fl_test = data.Lung_Dataset('val', verbose = 0)
fl_val = data.Lung_Dataset('test', verbose = 0)

"""
Data Split for Second Layer classification task (COVID vs Non-COVID) 
"""

sl_labels = {
0 : "COVID",
1 : "Non-COVID"
}

sl_train = data.Lung_Dataset('train', verbose = 2)
sl_test = data.Lung_Dataset('val', verbose = 2)
sl_val = data.Lung_Dataset('test', verbose = 2)

"""
Data Split for combined classification task (normal vs COVID vs Non-COVID) 
"""

combined_labels = {
0 : "Normal",
1 : "COVID",
2 : "Non-COVID"
}

final_val = data.Lung_Dataset('test', verbose = 1)
final_test = data.Lung_Dataset('val', verbose = 1)

# %% [markdown]
# Defining Model Parameters

# %%
N_EPOCH = 200
L_RATE_FL = 0.015482051772781362
BATCH_SIZE_FL = 16
DROPOUT_FL = 0.1258685286441622
WD_FL = 0.018373534139734887
L_RATE_SL = 0.00022040717935498526
BATCH_SIZE_SL = 64
DROPOUT_SL = 0.07216065625585566
WD_SL = 0.08267768486777832
PATIENCE = 10

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Training the First Layer Model

# %%
#First Model Training
fl_train_loader = DataLoader(fl_train, batch_size=BATCH_SIZE_FL, shuffle=True)
fl_val_loader = DataLoader(fl_val, batch_size=BATCH_SIZE_FL, shuffle=True)
fl_test_loader = DataLoader(fl_test, batch_size=BATCH_SIZE_FL, shuffle=True)
    
fl_model = model.CNN(dropout=DROPOUT_FL).to(device)
fl_optimizer = optim.AdamW(fl_model.parameters(), lr=L_RATE_FL, weight_decay=WD_FL)
    
print("Training the first model to classify normal and infected images")
model.train(fl_model, device, nn.BCELoss(), fl_optimizer, fl_train_loader, fl_val_loader, N_EPOCH, PATIENCE, "fl")

print("\n\n")
print("Test Accuracy of the first model:")
model.test(fl_model, device, fl_test_loader)

fl_model.to("cpu")
    
model.save_model(fl_model, fl_optimizer, './saved_models/fl_model.pth')
# Out:
# Training the first model to classify normal and infected images
#
#
# Epoch 1
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 3.53155002838526
# Validation set accuracy:  61.951219512195124 %
#
#
# Epoch 2
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 8.057859191527733
# Validation set accuracy:  61.951219512195124 %
#
#
# Epoch 3
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 0.6588148726866796
# Validation set accuracy:  71.70731707317073 %
#
#
# Epoch 4
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 2.3310800981827273
# Validation set accuracy:  64.55284552845528 %
#
#
# Epoch 5
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 1.0074003675045111
# Validation set accuracy:  59.51219512195122 %
#
#
# Epoch 6
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 1.7653854107245421
# Validation set accuracy:  63.2520325203252 %
#
#
# Epoch 7
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 0.9338105129889953
# Validation set accuracy:  70.73170731707317 %
#
#
# Epoch 8
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 2.261791915465624
# Validation set accuracy:  62.113821138211385 %
#
#
# Epoch 9
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 1.878789946054801
# Validation set accuracy:  50.08130081300813 %
#
#
# Epoch 10
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 1.2712758924716558
# Validation set accuracy:  69.7560975609756 %
#
#
# Epoch 11
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 0.4236564964820177
# Validation set accuracy:  82.27642276422765 %
#
#
# Epoch 12
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 0.9499594240616529
# Validation set accuracy:  74.3089430894309 %
#
#
# Epoch 13
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 1.8224015893080296
# Validation set accuracy:  63.08943089430894 %
#
#
# Epoch 14
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 1.678551741135426
# Validation set accuracy:  67.15447154471545 %
#
#
# Epoch 15
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 1.2112673803781853
# Validation set accuracy:  69.7560975609756 %
#
#
# Epoch 16
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 1.4172238990282402
# Validation set accuracy:  67.8048780487805 %
#
#
# Epoch 17
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 1.2883564600577722
# Validation set accuracy:  66.82926829268293 %
#
#
# Epoch 18
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 1.0392369081576665
# Validation set accuracy:  69.7560975609756 %
#
#
# Epoch 19
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 1.8060580858817468
# Validation set accuracy:  64.22764227642277 %
#
#
# Epoch 20
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 0.8897357262097872
# Validation set accuracy:  75.9349593495935 %
#
#
# Epoch 21
# HBox(children=(FloatProgress(value=0.0, max=326.0), HTML(value='')))
# Validation loss: 0.9843418418596952
# Validation set accuracy:  74.47154471544715 %
#
#
#
# Test Accuracy of the first model:
# Test set accuracy:  92.0 %

# %% [markdown]
# Training the Second Layer Model

# %%
#Second Model Training
sl_train_loader = DataLoader(sl_train, batch_size=BATCH_SIZE_SL, shuffle=True)
sl_val_loader = DataLoader(sl_val, batch_size=BATCH_SIZE_SL, shuffle=True)
sl_test_loader = DataLoader(sl_test, batch_size=BATCH_SIZE_SL, shuffle=True)
    
sl_model = model.CNN(dropout=DROPOUT_SL).to(device)  
sl_optimizer = optim.AdamW(sl_model.parameters(), lr=L_RATE_SL, weight_decay=WD_SL)
    
print("\n\n")
print("Training the second model to classify COVID and non-COVID images")
model.train(sl_model, device, nn.BCELoss(), sl_optimizer, sl_train_loader, sl_val_loader, N_EPOCH, PATIENCE, "sl")
    
print("\n\n")
print("Test Accuracy of the second model:")
model.test(sl_model, device, sl_test_loader)
    
sl_model.to("cpu")
    
model.save_model(sl_model, sl_optimizer, './saved_models/sl_model.pth')
# Out:
# Training the second model to classify COVID and non-COVID images
#
#
# Epoch 1
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.563805361588796
# Validation set accuracy:  81.36482939632546 %
#
#
# Epoch 2
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.44131530821323395
# Validation set accuracy:  81.62729658792651 %
#
#
# Epoch 3
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.37776800990104675
# Validation set accuracy:  91.33858267716535 %
#
#
# Epoch 4
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.35709687570730847
# Validation set accuracy:  93.1758530183727 %
#
#
# Epoch 5
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.38611818353335065
# Validation set accuracy:  91.0761154855643 %
#
#
# Epoch 6
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.33722903331120807
# Validation set accuracy:  91.0761154855643 %
#
#
# Epoch 7
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.3250760982433955
# Validation set accuracy:  90.81364829396325 %
#
#
# Epoch 8
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.3295835306247075
# Validation set accuracy:  92.38845144356955 %
#
#
# Epoch 9
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.3033543626467387
# Validation set accuracy:  93.96325459317585 %
#
#
# Epoch 10
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.3490348582466443
# Validation set accuracy:  88.18897637795276 %
#
#
# Epoch 11
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.34597838421662647
# Validation set accuracy:  85.56430446194226 %
#
#
# Epoch 12
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.3703208814064662
# Validation set accuracy:  82.67716535433071 %
#
#
# Epoch 13
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.33664947003126144
# Validation set accuracy:  87.66404199475066 %
#
#
# Epoch 14
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.30584079027175903
# Validation set accuracy:  92.38845144356955 %
#
#
# Epoch 15
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.3285126214226087
# Validation set accuracy:  88.97637795275591 %
#
#
# Epoch 16
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.344985269010067
# Validation set accuracy:  86.35170603674541 %
#
#
# Epoch 17
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.3093193769454956
# Validation set accuracy:  92.1259842519685 %
#
#
# Epoch 18
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.2976539234320323
# Validation set accuracy:  91.0761154855643 %
#
#
# Epoch 19
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.3590921362241109
# Validation set accuracy:  85.30183727034121 %
#
#
# Epoch 20
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.2712419231732686
# Validation set accuracy:  91.86351706036746 %
#
#
# Epoch 21
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.34363391250371933
# Validation set accuracy:  86.61417322834646 %
#
#
# Epoch 22
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.3037786657611529
# Validation set accuracy:  90.0262467191601 %
#
#
# Epoch 23
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.32871392369270325
# Validation set accuracy:  89.501312335958 %
#
#
# Epoch 24
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.3721323733528455
# Validation set accuracy:  85.30183727034121 %
#
#
# Epoch 25
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.3406706129511197
# Validation set accuracy:  86.8766404199475 %
#
#
# Epoch 26
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.4420019934574763
# Validation set accuracy:  79.26509186351706 %
#
#
# Epoch 27
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.31433212757110596
# Validation set accuracy:  88.4514435695538 %
#
#
# Epoch 28
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.3759608070055644
# Validation set accuracy:  84.25196850393701 %
#
#
# Epoch 29
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.3936958611011505
# Validation set accuracy:  85.56430446194226 %
#
#
# Epoch 30
# HBox(children=(FloatProgress(value=0.0, max=61.0), HTML(value='')))
# Validation loss: 0.4592802971601486
# Validation set accuracy:  79.5275590551181 %
#
#
#
# Test Accuracy of the second model:
# Test set accuracy:  52.94117647058823 %

# %% [markdown]
# Analyzing the performance of each model (first layer and second layer models)

# %% [markdown]
# Learning Curve of the First Layer Model

# %%
Image(filename='./saved_graphs/fl_learning_curve.png')

# %% [markdown]
# Learning Curve of the Second Layer Model

# %%
Image(filename='./saved_graphs/sl_learning_curve.png')

# %% [markdown]
# Combine the 2 Models and Test the results on validation and test

# %%
final_val_loader = DataLoader(final_val, batch_size=BATCH_SIZE_FL, shuffle=False)
final_test_loader = DataLoader(final_test, batch_size=BATCH_SIZE_FL, shuffle=False)
    
combined_model = model.load_combined('./saved_models/fl_model.pth','./saved_models/sl_model.pth',WD_FL ,L_RATE_FL, DROPOUT_FL, WD_SL, L_RATE_SL, DROPOUT_SL)
pred = combined_model.predict_loader(device, final_val_loader)
actual = torch.empty(0, 3).to(device)
for _, labels in final_val_loader:
    labels = labels.to(device)
    actual = torch.cat((actual, labels), 0)
print("Validation Results")
print("Accuracy: {}".format(model.accuracy(pred, actual)))
print("Precision: {}".format(model.precision(pred, actual)))
print("Recall: {}".format(model.recall(pred, actual)))
print()
pred = combined_model.predict_loader(device, final_test_loader)
actual = torch.empty(0, 3).to(device)
for _, labels in final_test_loader:
    labels = labels.to(device)
    actual = torch.cat((actual, labels), 0)

print("Test Results")
print("Accuracy: {}".format(model.accuracy(pred, actual)))
print("Precision: {}".format(model.precision(pred, actual)))
print("Recall: {}".format(model.recall(pred, actual)))

print("\n\n")
print("Visualizing the Test Set: ")
utils.generate_performance_display(final_test_loader, pred, combined_labels)
# Out:
# Validation Results
# Accuracy: 0.7869918346405029
# Precision: [0.7828054298642534, 0.6602564102564102, 0.8739495798319328]
# Recall: [0.7393162393162394, 0.7410071942446043, 0.859504132231405]
#
# Test Results
# Accuracy: 0.6399999856948853
# Precision: [0.875, 0.5, 0.6]
# Recall: [0.875, 0.6666666666666666, 0.375]
#
#
#
# Visualizing the Test Set:
