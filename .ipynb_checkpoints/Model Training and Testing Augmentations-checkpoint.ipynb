# %% [markdown]
# <h1> Deep Learning Small Project </h1>

# %%
# %matplotlib inline

# Display
from IPython.display import Image

# Torch
import torch
from torch.utils.data import DataLoader
from torch import optim, nn
from torchvision import transforms

# Custom
import data
import model
import utils

# %% [markdown]
# Defining Model Parameters

# %%
N_EPOCH = 200
PATIENCE = 7

FL_L_RATE = 0.001
FL_BATCH_SIZE = 32
FL_DROPOUT = 0.05
FL_WD = 0.01

SL_L_RATE = 0.01
SL_BATCH_SIZE = 64
SL_DROPOUT = 0.15
SL_WD = 0.01

augmentations = transforms.Compose([
    transforms.ToTensor(),
    transforms.CenterCrop((140,140)),
    transforms.RandomAffine(degrees = 0, translate = (0.05,0), scale=(1,1.1))
])



device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Using Custom Dataloader, Data Split for First Layer classification task (normal vs infected)

# %%
fl_labels = {
0 : "Normal",
1 : "Infected"
}

fl_train = data.Lung_Dataset('train', verbose = 0)
fl_test = data.Lung_Dataset('test', verbose = 0)
fl_val = data.Lung_Dataset('val', verbose = 0)

"""
Data Split for Second Layer classification task (COVID vs Non-COVID) 
"""

sl_labels = {
0 : "COVID",
1 : "Non-COVID"
}

sl_train = data.Lung_Dataset('train', verbose = 2)
sl_test = data.Lung_Dataset('test', verbose = 2)
sl_val = data.Lung_Dataset('val', verbose = 2)

"""
Data Split for combined classification task (normal vs COVID vs Non-COVID) 
"""

combined_labels = {
0 : "Normal",
1 : "COVID",
2 : "Non-COVID"
}

final_val = data.Lung_Dataset('test', verbose = 1)
final_test = data.Lung_Dataset('val', verbose = 1)

# %% [markdown]
# Training the First Layer Model

# %%
#First Model Training
fl_train_loader = DataLoader(fl_train, batch_size=FL_BATCH_SIZE, shuffle=True)
fl_val_loader = DataLoader(fl_val, batch_size=FL_BATCH_SIZE, shuffle=True)
fl_test_loader = DataLoader(fl_test, batch_size=FL_BATCH_SIZE, shuffle=True)
    
fl_model = model.CNN(dropout=FL_DROPOUT).to(device)
fl_optimizer = optim.AdamW(fl_model.parameters(), lr=FL_L_RATE, weight_decay = FL_WD)
    
print("Training the first model to classify normal and infected images")
model.train(fl_model, device, nn.BCELoss(), fl_optimizer, fl_train_loader, fl_val_loader, N_EPOCH, PATIENCE, "fl")

print("\n\n")
print("Test Accuracy of the first model:")
model.test(fl_model, device, fl_test_loader)

fl_model.to("cpu")
    
model.save_model(fl_model, fl_optimizer, './saved_models/fl_model_augmentations.pth')
# Out:
# Training the first model to classify normal and infected images
#
#
# Epoch 1
#   0%|          | 0/163 [00:00<?, ?it/s]
# Validation loss: 0.24188391864299774
# Validation set accuracy:  92.0 %
#
#
# Epoch 2
#   0%|          | 0/163 [00:00<?, ?it/s]
# Validation loss: 0.32906222343444824
# Validation set accuracy:  84.0 %
#
#
# Epoch 3
#   0%|          | 0/163 [00:00<?, ?it/s]
# Validation loss: 0.8769944310188293
# Validation set accuracy:  76.0 %
#
#
# Epoch 4
#   0%|          | 0/163 [00:00<?, ?it/s]
# Validation loss: 0.2467842400074005
# Validation set accuracy:  92.0 %
#
#
# Epoch 5
#   0%|          | 0/163 [00:00<?, ?it/s]
# Validation loss: 0.3277064561843872
# Validation set accuracy:  88.0 %
#
#
# Epoch 6
#   0%|          | 0/163 [00:00<?, ?it/s]
# Validation loss: 0.10510802268981934
# Validation set accuracy:  96.0 %
#
#
# Epoch 7
#   0%|          | 0/163 [00:00<?, ?it/s]
# Validation loss: 0.14915384352207184
# Validation set accuracy:  92.0 %
#
#
# Epoch 8
#   0%|          | 0/163 [00:00<?, ?it/s]
# Validation loss: 0.2376265972852707
# Validation set accuracy:  92.0 %
#
#
# Epoch 9
#   0%|          | 0/163 [00:00<?, ?it/s]
# Validation loss: 0.10987789183855057
# Validation set accuracy:  96.0 %
#
#
# Epoch 10
#   0%|          | 0/163 [00:00<?, ?it/s]
# Validation loss: 0.33985599875450134
# Validation set accuracy:  92.0 %
#
#
# Epoch 11
#   0%|          | 0/163 [00:00<?, ?it/s]
# Validation loss: 0.30467158555984497
# Validation set accuracy:  92.0 %
#
#
# Epoch 12
#   0%|          | 0/163 [00:00<?, ?it/s]
# Validation loss: 0.12502901256084442
# Validation set accuracy:  92.0 %
#
#
# Epoch 13
#   0%|          | 0/163 [00:00<?, ?it/s]
# Validation loss: 1.177450180053711
# Validation set accuracy:  80.0 %
#
#
#
# Test Accuracy of the first model:
# Test set accuracy:  80.16260162601625 %

# %% [markdown]
# Training the Second Layer Model

# %%
#Second Model Training
sl_train_loader = DataLoader(sl_train, batch_size=SL_BATCH_SIZE, shuffle=True)
sl_val_loader = DataLoader(sl_val, batch_size=SL_BATCH_SIZE, shuffle=True)
sl_test_loader = DataLoader(sl_test, batch_size=SL_BATCH_SIZE, shuffle=True)
    
sl_model = model.CNN(dropout=SL_DROPOUT).to(device)  
sl_optimizer = optim.Adam(sl_model.parameters(), lr=SL_L_RATE, weight_decay = SL_WD)
    
print("\n\n")
print("Training the second model to classify COVID and non-COVID images")
model.train(sl_model, device, nn.BCELoss(), sl_optimizer, sl_train_loader, sl_val_loader, N_EPOCH, PATIENCE, "sl")
    
print("\n\n")
print("Test Accuracy of the second model:")
model.test(sl_model, device, sl_test_loader)
    
sl_model.to("cpu")
    
model.save_model(sl_model, sl_optimizer, './saved_models/sl_model_augmentations.pth')
# Out:
# Training the second model to classify COVID and non-COVID images
#
#
# Epoch 1
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.8671379089355469
# Validation set accuracy:  47.05882352941177 %
#
#
# Epoch 2
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.8499822020530701
# Validation set accuracy:  47.05882352941177 %
#
#
# Epoch 3
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.9120635986328125
# Validation set accuracy:  47.05882352941177 %
#
#
# Epoch 4
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.7974386811256409
# Validation set accuracy:  47.05882352941177 %
#
#
# Epoch 5
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.6370540857315063
# Validation set accuracy:  64.70588235294117 %
#
#
# Epoch 6
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.7051301598548889
# Validation set accuracy:  64.70588235294117 %
#
#
# Epoch 7
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.8172352910041809
# Validation set accuracy:  47.05882352941177 %
#
#
# Epoch 8
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.8383450508117676
# Validation set accuracy:  47.05882352941177 %
#
#
# Epoch 9
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.7811754941940308
# Validation set accuracy:  47.05882352941177 %
#
#
# Epoch 10
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.7754734754562378
# Validation set accuracy:  47.05882352941177 %
#
#
# Epoch 11
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.6671877503395081
# Validation set accuracy:  52.94117647058823 %
#
#
# Epoch 12
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.7290500402450562
# Validation set accuracy:  52.94117647058823 %
#
#
#
# Test Accuracy of the second model:
# Test set accuracy:  77.95275590551181 %

# %% [markdown]
# Analyzing the performance of each model (first layer and second layer models)

# %% [markdown]
# Learning Curve of the First Layer Model

# %%
Image(filename='./saved_graphs/fl_learning_curve.png')

# %% [markdown]
# Learning Curve of the Second Layer Model

# %%
Image(filename='./saved_graphs/sl_learning_curve.png')

# %% [markdown]
# Combine the 2 Models and Test the results on validation and test

# %%
final_val_loader = DataLoader(final_val, batch_size=FL_BATCH_SIZE, shuffle=False)
final_test_loader = DataLoader(final_test, batch_size=FL_BATCH_SIZE, shuffle=False)
    
combined_model = model.load_combined('./saved_models/fl_model_augmentations.pth','./saved_models/sl_model_augmentations.pth' ,
                                     FL_L_RATE, FL_DROPOUT, FL_WD, SL_L_RATE, SL_DROPOUT, SL_WD)
pred = combined_model.predict_loader(device, final_val_loader)
actual = torch.empty(0, 3).to(device)
for _, labels in final_val_loader:
    labels = labels.to(device)
    actual = torch.cat((actual, labels), 0)
print("Validation Results")
print("Accuracy: {}".format(model.accuracy(pred, actual)))
print("Precision: {}".format(model.precision(pred, actual)))
print("Recall: {}".format(model.recall(pred, actual)))
print()
pred = combined_model.predict_loader(device, final_test_loader)
actual = torch.empty(0, 3).to(device)
for _, labels in final_test_loader:
    labels = labels.to(device)
    actual = torch.cat((actual, labels), 0)

print("Test Results")
print("Accuracy: {}".format(model.accuracy(pred, actual)))
print("Precision: {}".format(model.precision(pred, actual)))
print("Recall: {}".format(model.recall(pred, actual)))

print("\n\n")
print("Visualizing the Test Set: ")
utils.generate_performance_display(final_test_loader, pred, combined_labels)
# Out:
# Validation Results
# Accuracy: 0.6682926416397095
# Precision: [0.9590163934426229, 0.4200743494423792, 0.8080357142857143]
# Recall: [0.5, 0.8129496402877698, 0.7479338842975206]
#
# Test Results
# Accuracy: 0.7199999690055847
# Precision: [1.0, 0.5625, 1.0]
# Recall: [0.875, 1.0, 0.25]
#
#
#
# Visualizing the Test Set:
