# %% [markdown]
# <h1> Deep Learning Small Project (Including Learning Rate Scheduler) </h1>

# %%
# %matplotlib inline

# Display
from IPython.display import Image

# Torch
import torch
from torch.utils.data import DataLoader
from torch import optim, nn

# Custom
import data
import LR_model as model
import LR_utils as utils

# %% [markdown]
# Using Custom Dataloader, Data Split for First Layer classification task (normal vs infected)

# %%
fl_labels = {
0 : "Normal",
1 : "Infected"
}

fl_train = data.Lung_Dataset('train', verbose = 0)
fl_test = data.Lung_Dataset('val', verbose = 0)
fl_val = data.Lung_Dataset('test', verbose = 0)

"""
Data Split for Second Layer classification task (COVID vs Non-COVID) 
"""

sl_labels = {
0 : "COVID",
1 : "Non-COVID"
}

sl_train = data.Lung_Dataset('train', verbose = 2)
sl_test = data.Lung_Dataset('val', verbose = 2)
sl_val = data.Lung_Dataset('test', verbose = 2)

"""
Data Split for combined classification task (normal vs COVID vs Non-COVID) 
"""

combined_labels = {
0 : "Normal",
1 : "COVID",
2 : "Non-COVID"
}

final_val = data.Lung_Dataset('test', verbose = 1)
final_test = data.Lung_Dataset('val', verbose = 1)

# %% [markdown]
# Defining Model Parameters

# %%
N_EPOCH = 200
L_RATE_FL = 0.015482051772781362
BATCH_SIZE_FL = 16
DROPOUT_FL = 0.1258685286441622
WD_FL = 0.018373534139734887
L_RATE_SL = 0.00022040717935498526
BATCH_SIZE_SL = 64
DROPOUT_SL = 0.07216065625585566
WD_SL = 0.08267768486777832
PATIENCE = 10
FL_STEPS = 11
SL_STEPS = 5

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Training the First Layer Model

# %%
#First Model Training
fl_train_loader = DataLoader(fl_train, batch_size=BATCH_SIZE_FL, shuffle=True)
fl_val_loader = DataLoader(fl_val, batch_size=BATCH_SIZE_FL, shuffle=True)
fl_test_loader = DataLoader(fl_test, batch_size=BATCH_SIZE_FL, shuffle=True)
    
fl_model = model.CNN(dropout=DROPOUT_FL).to(device)
fl_optimizer = optim.AdamW(fl_model.parameters(), lr=L_RATE_FL, weight_decay=WD_FL)
fl_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(fl_optimizer, FL_STEPS)
    
print("Training the first model to classify normal and infected images")
model.train(fl_model, device, nn.BCELoss(), fl_optimizer, fl_train_loader, fl_val_loader, N_EPOCH, PATIENCE, "fl", fl_scheduler, FL_STEPS)

print("\n\n")
print("Test Accuracy of the first model:")
model.test(fl_model, device, fl_test_loader)

fl_model.to("cpu")
    
model.save_model(fl_model, fl_optimizer, './saved_models/LR_fl_model.pth')
# Out:
# Training the first model to classify normal and infected images
#
#
# Epoch 1
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 0.5958085686732562
# Validation set accuracy:  70.40650406504065 %
#
#
# Epoch 2
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 0.8049638989644173
# Validation set accuracy:  67.3170731707317 %
#
#
# Epoch 3
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 0.5951489878770633
# Validation set accuracy:  80.0 %
#
#
# Epoch 4
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.999888478181301
# Validation set accuracy:  62.60162601626016 %
#
#
# Epoch 5
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 10.447822057283842
# Validation set accuracy:  61.951219512195124 %
#
#
# Epoch 6
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 3.3243122528760862
# Validation set accuracy:  41.46341463414634 %
#
#
# Epoch 7
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.529219816128413
# Validation set accuracy:  66.01626016260163 %
#
#
# Epoch 8
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 0.816431408891311
# Validation set accuracy:  73.33333333333333 %
#
#
# Epoch 9
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.83279764575836
# Validation set accuracy:  65.04065040650407 %
#
#
# Epoch 10
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.3557569422782996
# Validation set accuracy:  72.84552845528455 %
#
#
# Epoch 11
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 0.5881375288351988
# Validation set accuracy:  82.76422764227642 %
#
#
# Epoch 12
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.1867502553340716
# Validation set accuracy:  73.4959349593496 %
#
#
# Epoch 13
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.1075946405912056
# Validation set accuracy:  71.70731707317073 %
#
#
# Epoch 14
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.695608080866245
# Validation set accuracy:  68.6178861788618 %
#
#
# Epoch 15
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.145897496969272
# Validation set accuracy:  70.5691056910569 %
#
#
# Epoch 16
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 2.4139879170136576
# Validation set accuracy:  64.71544715447155 %
#
#
# Epoch 17
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.1836013266673455
# Validation set accuracy:  73.98373983739837 %
#
#
# Epoch 18
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.0251230012912016
# Validation set accuracy:  79.51219512195122 %
#
#
# Epoch 19
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 0.558791050947128
# Validation set accuracy:  85.52845528455285 %
#
#
# Epoch 20
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.2692433645327885
# Validation set accuracy:  71.70731707317073 %
#
#
# Epoch 21
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.4169111874623177
# Validation set accuracy:  75.9349593495935 %
#
#
# Epoch 22
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.3501426150592475
# Validation set accuracy:  78.3739837398374 %
#
#
# Epoch 23
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.8271797076345255
# Validation set accuracy:  69.7560975609756 %
#
#
# Epoch 24
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.187623876791734
# Validation set accuracy:  74.95934959349593 %
#
#
# Epoch 25
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 2.1449160224352126
# Validation set accuracy:  68.6178861788618 %
#
#
# Epoch 26
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.4384389966726303
# Validation set accuracy:  73.65853658536585 %
#
#
# Epoch 27
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.3107699560813415
# Validation set accuracy:  75.28455284552845 %
#
#
# Epoch 28
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.4902887350091567
# Validation set accuracy:  74.95934959349593 %
#
#
# Epoch 29
#   0%|          | 0/326 [00:00<?, ?it/s]
# Validation loss: 1.4661193228302858
# Validation set accuracy:  75.60975609756098 %
#
#
#
# Test Accuracy of the first model:
# Test set accuracy:  92.0 %

# %% [markdown]
# Training the Second Layer Model

# %%
#Second Model Training
sl_train_loader = DataLoader(sl_train, batch_size=BATCH_SIZE_SL, shuffle=True)
sl_val_loader = DataLoader(sl_val, batch_size=BATCH_SIZE_SL, shuffle=True)
sl_test_loader = DataLoader(sl_test, batch_size=BATCH_SIZE_SL, shuffle=True)
    
sl_model = model.CNN(dropout=DROPOUT_SL).to(device)  
sl_optimizer = optim.AdamW(sl_model.parameters(), lr=L_RATE_SL, weight_decay=WD_SL)
sl_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(sl_optimizer, SL_STEPS)

print("\n\n")
print("Training the second model to classify COVID and non-COVID images")
model.train(sl_model, device, nn.BCELoss(), sl_optimizer, sl_train_loader, sl_val_loader, N_EPOCH, PATIENCE, "sl", sl_scheduler,SL_STEPS)
    
print("\n\n")
print("Test Accuracy of the second model:")
model.test(sl_model, device, sl_test_loader)
    
sl_model.to("cpu")
    
model.save_model(sl_model, sl_optimizer, './saved_models/LR_sl_model.pth')
# Out:
# Training the second model to classify COVID and non-COVID images
#
#
# Epoch 1
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.5488957762718201
# Validation set accuracy:  75.06561679790026 %
#
#
# Epoch 2
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.4446592628955841
# Validation set accuracy:  86.8766404199475 %
#
#
# Epoch 3
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.45065362254778546
# Validation set accuracy:  88.97637795275591 %
#
#
# Epoch 4
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3885582586129506
# Validation set accuracy:  88.18897637795276 %
#
#
# Epoch 5
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3863740414381027
# Validation set accuracy:  89.23884514435696 %
#
#
# Epoch 6
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.38185687859853107
# Validation set accuracy:  90.0262467191601 %
#
#
# Epoch 7
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.35895466804504395
# Validation set accuracy:  88.18897637795276 %
#
#
# Epoch 8
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.39235004285971325
# Validation set accuracy:  85.8267716535433 %
#
#
# Epoch 9
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.38993508120377857
# Validation set accuracy:  83.72703412073491 %
#
#
# Epoch 10
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.36360767980416614
# Validation set accuracy:  86.61417322834646 %
#
#
# Epoch 11
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3808610488971074
# Validation set accuracy:  84.7769028871391 %
#
#
# Epoch 12
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3672252992788951
# Validation set accuracy:  86.35170603674541 %
#
#
# Epoch 13
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.4497913718223572
# Validation set accuracy:  73.22834645669292 %
#
#
# Epoch 14
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3482521076997121
# Validation set accuracy:  89.501312335958 %
#
#
# Epoch 15
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3655262390772502
# Validation set accuracy:  85.30183727034121 %
#
#
# Epoch 16
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.39948832988739014
# Validation set accuracy:  80.5774278215223 %
#
#
# Epoch 17
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3754625767469406
# Validation set accuracy:  85.03937007874016 %
#
#
# Epoch 18
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.38499964276949566
# Validation set accuracy:  83.2020997375328 %
#
#
# Epoch 19
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.35253624121348065
# Validation set accuracy:  87.66404199475066 %
#
#
# Epoch 20
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.35455916821956635
# Validation set accuracy:  86.35170603674541 %
#
#
# Epoch 21
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.33841248353322345
# Validation set accuracy:  89.501312335958 %
#
#
# Epoch 22
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3752596129973729
# Validation set accuracy:  85.56430446194226 %
#
#
# Epoch 23
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.34777650237083435
# Validation set accuracy:  86.61417322834646 %
#
#
# Epoch 24
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3528776317834854
# Validation set accuracy:  86.35170603674541 %
#
#
# Epoch 25
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3115348716576894
# Validation set accuracy:  90.0262467191601 %
#
#
# Epoch 26
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3724125822385152
# Validation set accuracy:  85.03937007874016 %
#
#
# Epoch 27
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.37414276599884033
# Validation set accuracy:  83.72703412073491 %
#
#
# Epoch 28
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.29066426555315655
# Validation set accuracy:  91.86351706036746 %
#
#
# Epoch 29
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3975360045830409
# Validation set accuracy:  79.79002624671917 %
#
#
# Epoch 30
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.38191478947798413
# Validation set accuracy:  81.36482939632546 %
#
#
# Epoch 31
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3452797482411067
# Validation set accuracy:  86.8766404199475 %
#
#
# Epoch 32
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3286166737476985
# Validation set accuracy:  86.08923884514435 %
#
#
# Epoch 33
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.37013960381348926
# Validation set accuracy:  83.72703412073491 %
#
#
# Epoch 34
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.32753826181093854
# Validation set accuracy:  90.81364829396325 %
#
#
# Epoch 35
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.4103744899233182
# Validation set accuracy:  80.05249343832021 %
#
#
# Epoch 36
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3737824906905492
# Validation set accuracy:  81.62729658792651 %
#
#
# Epoch 37
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.3436634341875712
# Validation set accuracy:  84.25196850393701 %
#
#
# Epoch 38
#   0%|          | 0/61 [00:00<?, ?it/s]
# Validation loss: 0.43405236303806305
# Validation set accuracy:  79.79002624671917 %
#
#
#
# Test Accuracy of the second model:
# Test set accuracy:  64.70588235294117 %

# %% [markdown]
# Analyzing the performance of each model (first layer and second layer models)

# %% [markdown]
# Learning Curve of the First Layer Model

# %%
Image(filename='./saved_graphs/fl_learning_curve.png')

# %% [markdown]
# Learning Curve of the Second Layer Model

# %%
Image(filename='./saved_graphs/sl_learning_curve.png')

# %% [markdown]
# Combine the 2 Models and Test the results on validation and test

# %%
final_val_loader = DataLoader(final_val, batch_size=BATCH_SIZE_FL, shuffle=False)
final_test_loader = DataLoader(final_test, batch_size=BATCH_SIZE_FL, shuffle=False)
    
combined_model = model.load_combined('./saved_models/fl_model.pth','./saved_models/sl_model.pth',WD_FL ,L_RATE_FL, DROPOUT_FL, WD_SL, L_RATE_SL, DROPOUT_SL)
pred = combined_model.predict_loader(device, final_val_loader)
actual = torch.empty(0, 3).to(device)
for _, labels in final_val_loader:
    labels = labels.to(device)
    actual = torch.cat((actual, labels), 0)
print("Validation Results")
print("Accuracy: {}".format(model.accuracy(pred, actual)))
print("Precision: {}".format(model.precision(pred, actual)))
print("Recall: {}".format(model.recall(pred, actual)))
print()
pred = combined_model.predict_loader(device, final_test_loader)
actual = torch.empty(0, 3).to(device)
for _, labels in final_test_loader:
    labels = labels.to(device)
    actual = torch.cat((actual, labels), 0)

print("Test Results")
print("Accuracy: {}".format(model.accuracy(pred, actual)))
print("Precision: {}".format(model.precision(pred, actual)))
print("Recall: {}".format(model.recall(pred, actual)))

print("\n\n")
print("Visualizing the Test Set: ")
utils.generate_performance_display(final_test_loader, pred, combined_labels)
# Out:
# Validation Results
# Accuracy: 0.8081300854682922
# Precision: [0.9393939393939394, 0.7074829931972789, 0.7854785478547854]
# Recall: [0.6623931623931624, 0.7482014388489209, 0.9834710743801653]
#
# Test Results
# Accuracy: 0.6800000071525574
# Precision: [1.0, 0.5833333333333334, 0.5714285714285714]
# Recall: [0.75, 0.7777777777777778, 0.5]
#
#
#
# Visualizing the Test Set:
